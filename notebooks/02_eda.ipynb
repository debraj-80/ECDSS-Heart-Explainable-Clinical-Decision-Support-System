# %% [markdown]
# # 02 - Exploratory Data Analysis
#
# Statistical analysis and visualization of the UCI Heart Disease dataset.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data.load_data import load_and_merge
from src.data.preprocess import preprocess_dataframe, binary_target

# %%
df = load_and_merge('../data/raw')
df = preprocess_dataframe(df)
df = binary_target(df)
print(f'Dataset shape: {df.shape}')

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe().round(2)

# %% [markdown]
# ## Target Distribution

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='target', data=df, palette='Set2')
plt.title('Target Distribution (0=No Disease, 1=Disease)')
plt.xlabel('Target')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(14, 10))
correlation = df.corr()
sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Distributions

# %%
numeric_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
for i, feature in enumerate(numeric_features):
    ax = axes[i // 3, i % 3]
    sns.histplot(data=df, x=feature, hue='target', kde=True, ax=ax, palette='Set2')
    ax.set_title(f'{feature} Distribution')
axes[1, 2].set_visible(False)
plt.tight_layout()
plt.show()
