# %% [markdown]
# # 01 - Data Preparation
#
# Load and prepare the UCI Heart Disease datasets.
#
# **Dataset Sources:**
# - Cleveland Clinic Foundation
# - Hungarian Institute of Cardiology
# - University Hospital, Zurich
# - VA Medical Center, Long Beach

# %%
import sys
sys.path.insert(0, '..')

from src.data.download_data import download_datasets
from src.data.load_data import load_and_merge
from src.data.preprocess import preprocess_dataframe, binary_target

# %% [markdown]
# ## Load Datasets

# %%
# Download datasets (skips if already downloaded)
downloaded_files = download_datasets('../data/raw')
print(f'Downloaded {len(downloaded_files)} datasets')

# Load and merge
df = load_and_merge('../data/raw')
print(f'Dataset shape: {df.shape}')

# %% [markdown]
# ## Dataset Dimensions

# %%
print(f'Rows: {df.shape[0]}')
print(f'Columns: {df.shape[1]}')
print(f'Features: {list(df.columns)}')

# %% [markdown]
# ## Missing Values

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_pct
})
print(missing_df[missing_df['Missing Count'] > 0])

# %% [markdown]
# ## Target Distribution

# %%
# Convert target to binary
df = binary_target(df)

print('Target distribution (binary):')
print(df['target'].value_counts())
print(f'\nClass balance: {df["target"].value_counts(normalize=True).round(3).to_dict()}')

# %% [markdown]
# ## Data Cleaning

# %%
df_clean = preprocess_dataframe(df)
print(f'Shape after cleaning: {df_clean.shape}')
print(f'Remaining NaN: {df_clean.isnull().sum().sum()}')
